# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r"C:\Users\VIVEK KUMAR SHARMA\Downloads\device_data_1.xls")

# %%
data.head()
# Out:
#                                                 Time       Devicename  \
# 0  Wed Jul 07 2021 14:15:09 GMT+0530 (India Stand...  867378035207325
# 1  Wed Jul 07 2021 14:16:14 GMT+0530 (India Stand...  867378035207325
# 2  Wed Jul 07 2021 14:17:18 GMT+0530 (India Stand...  867378035207325
# 3  Wed Jul 07 2021 14:18:23 GMT+0530 (India Stand...  867378035207325
# 4  Wed Jul 07 2021 14:19:28 GMT+0530 (India Stand...  867378035207325
#
#    Temperature  TDS        PH    DO
# 0      29.0625  0.0  13.61598  9.91
# 1      29.0625  0.0  13.12313  9.90
# 2      29.0000  0.0  13.55723  9.90
# 3      29.0625  0.0  14.00000  9.90
# 4      29.0625  0.0  14.00000  9.90

# %%
data=data.round(0)
data.head(5)
# Out:
#                                                 Time       Devicename  \
# 0  Wed Jul 07 2021 14:15:09 GMT+0530 (India Stand...  867378035207325
# 1  Wed Jul 07 2021 14:16:14 GMT+0530 (India Stand...  867378035207325
# 2  Wed Jul 07 2021 14:17:18 GMT+0530 (India Stand...  867378035207325
# 3  Wed Jul 07 2021 14:18:23 GMT+0530 (India Stand...  867378035207325
# 4  Wed Jul 07 2021 14:19:28 GMT+0530 (India Stand...  867378035207325
#
#    Temperature  TDS    PH    DO
# 0         29.0  0.0  14.0  10.0
# 1         29.0  0.0  13.0  10.0
# 2         29.0  0.0  14.0  10.0
# 3         29.0  0.0  14.0  10.0
# 4         29.0  0.0  14.0  10.0

# %%
data.isnull().sum()
# Out:
# Time           0
# Devicename     0
# Temperature    0
# TDS            0
# PH             0
# DO             0
# dtype: int64

# %%
col= ['Temperature', 'TDS', 'PH', 'DO']
data1=data[col]

# %%
data= pd.get_dummies(data)
data.head(5)
# Out:
#         Devicename  Temperature  TDS    PH    DO  \
# 0  867378035207325         29.0  0.0  14.0  10.0
# 1  867378035207325         29.0  0.0  13.0  10.0
# 2  867378035207325         29.0  0.0  14.0  10.0
# 3  867378035207325         29.0  0.0  14.0  10.0
# 4  867378035207325         29.0  0.0  14.0  10.0
#
#    Time_Mon Jul 19 2021 20:17:50 GMT+0530 (India Standard Time)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Time_Mon Jul 19 2021 20:18:55 GMT+0530 (India Standard Time)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
data.columns
# Out:
# Index(['Devicename', 'Temperature', 'TDS', 'PH', 'DO',
#        'Time_Mon Jul 19 2021 20:17:50 GMT+0530 (India Standard Time)',
#        'Time_Mon Jul 19 2021 20:18:55 GMT+0530 (India Standard Time)',
#        'Time_Mon Jul 19 2021 20:19:59 GMT+0530 (India Standard Time)',
#        'Time_Mon Jul 19 2021 20:21:04 GMT+0530 (India Standard Time)',
#        'Time_Mon Jul 19 2021 20:22:08 GMT+0530 (India Standard Time)',
#        ...
#        'Time_Wed Jul 28 2021 17:25:54 GMT+0530 (India Standard Time)',
#        'Time_Wed Jul 28 2021 17:26:59 GMT+0530 (India Standard Time)',
#        'Time_Wed Jul 28 2021 17:28:04 GMT+0530 (India Standard Time)',
#        'Time_Wed Jul 28 2021 17:29:08 GMT+0530 (India Standard Time)',
#        'Time_Wed Jul 28 2021 17:30:13 GMT+0530 (India Standard Time)',
#        'Time_Wed Jul 28 2021 17:31:18 GMT+0530 (India Standard Time)',
#        'Time_Wed Jul 28 2021 17:32:23 GMT+0530 (India Standard Time)',
# ...

# %%
list(data.columns)
# Out:
# ['Devicename',
#  'Temperature',
#  'TDS',
#  'PH',
#  'DO',
#  'Time_Mon Jul 19 2021 20:17:50 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:18:55 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:19:59 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:21:04 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:22:08 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:23:13 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:24:17 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:25:22 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:26:27 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:27:31 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:28:36 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:29:41 GMT+0530 (India Standard Time)',
#  'Time_Mon Jul 19 2021 20:30:45 GMT+0530 (India Standard Time)',
# ...

# %%
y=data["DO"]
feature=['Temperature', 'TDS', 'PH',
       'Time_Mon Jul 19 2021 20:17:50 GMT+0530 (India Standard Time)',
 'Time_Mon Jul 19 2021 20:18:55 GMT+0530 (India Standard Time)',
 'Time_Mon Jul 19 2021 20:19:59 GMT+0530 (India Standard Time)',
 'Time_Mon Jul 19 2021 20:21:04 GMT+0530 (India Standard Time)']

# %%
x=data[feature]

# %%
x.head(2)
# Out:
#    Temperature  TDS    PH  \
# 0         29.0  0.0  14.0
# 1         29.0  0.0  13.0
#
#    Time_Mon Jul 19 2021 20:17:50 GMT+0530 (India Standard Time)  \
# 0                                                  0
# 1                                                  0
#
#    Time_Mon Jul 19 2021 20:18:55 GMT+0530 (India Standard Time)  \
# 0                                                  0
# 1                                                  0
#
#    Time_Mon Jul 19 2021 20:19:59 GMT+0530 (India Standard Time)  \
# 0                                                  0
# 1                                                  0
#
#    Time_Mon Jul 19 2021 20:21:04 GMT+0530 (India Standard Time)
# 0                                                  0
# 1                                                  0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.25, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso(alpha=0.1, normalize=True)

# %%
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1, normalize=True)

# %%
lasso_pred= lasso.predict(x_test)

# %%
lasso.score(x_test, y_test)
# Out:
# -0.00017307794708076862

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test, y_test)
# Out:
# 0.5778718511704517

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg=LogisticRegression()

# %%
logreg.fit(x_train,y_train)
# Out:
# C:\Users\VIVEK KUMAR SHARMA\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logreg.score(x_test, y_test)
# Out:
# 0.5833333333333334

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
n_estimators=[1,2,4,8,16,32,64,100,200]
train_results=[]
test_results=[]

# %%
rf=RandomForestClassifier(n_jobs=-1, max_features = "auto", random_state=42, min_samples_leaf = 1)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
rf.score(x_test, y_test)
# Out:
# 0.6909722222222222
